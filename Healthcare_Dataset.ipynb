# %% [markdown]
# <a href="https://colab.research.google.com/github/malakbayramovaa/Machine-Learning/blob/main/Healthcare_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/healthcare_dataset.csv')
df.head(5)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306        328.0         Urgent     2024-02-02  Paracetamol
# 1    33643.327287        265.0      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079        205.0      Emergency     2022-10-07      Aspirin
# 3    37909.782410        450.0       Elective     2020-12-18    Ibuprofen
# 4    14238.317814        458.0         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])
# Out:
# Rows: 6932
# Columns: 15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6932 entries, 0 to 6931
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                6932 non-null   object
#  1   Age                 6932 non-null   int64
#  2   Gender              6932 non-null   object
#  3   Blood Type          6932 non-null   object
#  4   Medical Condition   6932 non-null   object
#  5   Date of Admission   6932 non-null   object
#  6   Doctor              6932 non-null   object
#  7   Hospital            6932 non-null   object
#  8   Insurance Provider  6932 non-null   object
#  9   Billing Amount      6932 non-null   float64
#  10  Room Number         6931 non-null   float64
#  11  Admission Type      6931 non-null   object
#  12  Discharge Date      6931 non-null   object
#  13  Medication          6931 non-null   object
#  14  Test Results        6931 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 812.5+ KB

# %%
df.describe()
# Out:
#                Age  Billing Amount  Room Number
# count  6932.000000     6932.000000  6931.000000
# mean     51.898009    25617.393527   299.347280
# std      19.766480    14165.407943   115.485346
# min      18.000000    -1310.272895   101.000000
# 25%      35.000000    13350.827324   201.000000
# 50%      52.000000    25724.602718   302.000000
# 75%      69.000000    37739.926830   396.000000
# max      85.000000    52271.663747   500.000000

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number           float64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df['Date of Admission']=pd.to_datetime(df['Date of Admission'])

# %%
df['Discharge Date']=pd.to_datetime(df['Discharge Date'])

# %%
df.dtypes
# Out:
# Name                          object
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                  float64
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# dtype: object

# %%
df.head(3)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
#
#              Doctor         Hospital Insurance Provider  Billing Amount  \
# 0     Matthew Smith  Sons and Miller         Blue Cross    18856.281306
# 1   Samantha Davies          Kim Inc           Medicare    33643.327287
# 2  Tiffany Mitchell         Cook PLC              Aetna    27955.096079
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0        328.0         Urgent     2024-02-02  Paracetamol        Normal
# 1        265.0      Emergency     2019-08-26    Ibuprofen  Inconclusive
# 2        205.0      Emergency     2022-10-07      Aspirin        Normal

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           1
# Admission Type        1
# Discharge Date        1
# Medication            1
# Test Results          1
# dtype: int64

# %%
df['Medical Condition'].value_counts()
# Out:
# Medical Condition
# Asthma          1161
# Arthritis       1160
# Cancer          1159
# Diabetes        1156
# Hypertension    1154
# Obesity         1142
# Name: count, dtype: int64

# %%
df['Medication'].nunique()
# Out:
# 5

# %%
df['Medication'].value_counts()
# Out:
# Medication
# Penicillin     1430
# Ibuprofen      1412
# Lipitor        1391
# Aspirin        1357
# Paracetamol    1341
# Name: count, dtype: int64

# %%
df['Hospital'].nunique()
# Out:
# 6465

# %%
df['Insurance Provider'].nunique()
# Out:
# 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Insurance Provider', y='Billing Amount', data=df)
plt.title('Billing Amount by Insurance Provider')
plt.show()

# %%
sns.boxplot(x=df['Blood Type'])
plt.show()

# %%
Q1 = df['Billing Amount'].quantile(0.25)
Q3 = df['Billing Amount'].quantile(0.75)

IQR = Q3 - Q1

outliers = df[(df['Billing Amount'] < Q1 - 1.5*IQR) | (df['Billing Amount'] > Q3 + 1.5*IQR)]
outliers
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Blood Type, Medical Condition, Date of Admission, Doctor, Hospital, Insurance Provider, Billing Amount, Room Number, Admission Type, Discharge Date, Medication, Test Results]
# Index: []

# %%
df['Medical Condition'].hist(bins=12)
plt.title('Medical Condition Count')
plt.xlabel('Medical condition')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='Admission Type', data=df)
plt.title('Type Count')
plt.xlabel('Admission Type')
plt.ylabel('Count')
plt.show()

# %%
df['Test Results'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Ödəniş Metodları Payı')
plt.show()

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
df['Admission Year'] = df['Date of Admission'].dt.year
sns.countplot(x='Admission Year', data=df)
plt.title('Number of Admissions per Year')
plt.show()

# %%
sns.catplot(x='Medical Condition', hue='Test Results', kind='count', data=df, height=5, aspect=2)
plt.xticks(rotation=45)
plt.title('Medical Condition vs Test Results')
plt.show()

# %%
df.groupby('Gender')['Billing Amount'].mean()
# Out:
# Gender
# Female    25554.843812
# Male      25679.907160
# Name: Billing Amount, dtype: float64

# %%
billing_stats = df.groupby('Medical Condition')['Billing Amount'].agg(['mean','median','max','min'])
billing_stats
# Out:
#                            mean        median           max          min
# Medical Condition
# Arthritis          25749.368477  25976.815940  52170.036854  -692.408820
# Asthma             25958.759372  26305.261294  52181.837792 -1018.245371
# Cancer             25958.181126  25804.598342  51082.323868  -502.507813
# Diabetes           25020.083395  24747.019858  51214.834358  -576.727907
# Hypertension       25549.864962  25791.085849  52271.663747  -370.983674
# Obesity            25463.303304  26010.761701  51441.729053 -1310.272895

# %%
df['Length of Stay'] = (df['Discharge Date'] - df['Date of Admission']).dt.days

stay_stats = df.groupby(['Medical Condition','Admission Type'])['Length of Stay'].mean().sort_values(ascending=False).reset_index()
stay_stats
# Out:
#    Medical Condition Admission Type  Length of Stay
# 0             Cancer      Emergency       16.333333
# 1             Asthma       Elective       16.286064
# 2             Asthma      Emergency       16.026042
# 3            Obesity      Emergency       15.881890
# 4           Diabetes       Elective       15.601583
# 5            Obesity         Urgent       15.578554
# 6             Cancer       Elective       15.509901
# 7          Arthritis         Urgent       15.497500
# 8             Asthma         Urgent       15.486413
# 9       Hypertension         Urgent       15.481771
# 10      Hypertension      Emergency       15.454294
# 11          Diabetes         Urgent       15.325521
# 12      Hypertension       Elective       15.325183
# 13           Obesity       Elective       15.319444
# 14         Arthritis      Emergency       15.279452
# 15         Arthritis       Elective       15.273418
# 16            Cancer         Urgent       15.189560
# 17          Diabetes      Emergency       14.256997

# %%
# Age group yarat
bins = [0, 18, 35, 50, 65, 100]
labels = ['0-18','19-35','36-50','51-65','66+']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels)

# Age Group vs Medical Condition
age_condition = df.groupby(['Age Group','Medical Condition']).size().unstack(fill_value=0)
age_condition
# Out:
# /tmp/ipython-input-4275997197.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_condition = df.groupby(['Age Group','Medical Condition']).size().unstack(fill_value=0)
# Medical Condition  Arthritis  Asthma  Cancer  Diabetes  Hypertension  Obesity
# Age Group
# 0-18                      14      18      18        23            18       14
# 19-35                    278     263     292       299           283      248
# 36-50                    251     267     271       251           247      266
# 51-65                    265     248     244       241           246      266
# 66+                      352     365     334       342           360      348

# %%
doctor_stats = df.groupby('Doctor')['Billing Amount'].agg(['count','mean']).sort_values(by='count', ascending=False).reset_index()
doctor_stats
# Out:
#                Doctor  count          mean
# 0       Matthew Smith      5  24895.873214
# 1          John Smith      4  22991.647947
# 2         James Smith      4  30173.854376
# 3     Michael Johnson      4  18968.557136
# 4        Daniel Smith      4  28166.777248
# ...               ...    ...           ...
# 6627         Ethan Li      1   7753.111014
# 6628      Ethan Lewis      1  33025.403263
# 6629      Ethan Brock      1  20773.023319
# 6630     Ethan Bowman      1  15592.464527
# 6631    Evan Ferguson      1  24525.748815
#
# [6632 rows x 3 columns]

# %%
med_test = df.groupby(['Medication','Test Results']).size().unstack(fill_value=0)
med_test_percent = med_test.div(med_test.sum(axis=1), axis=0) * 100
med_test_percent
# Out:
# Test Results   Abnormal  Inconclusive     Normal
# Medication
# Aspirin       34.266765     32.940310  32.792926
# Ibuprofen     34.490085     34.206799  31.303116
# Lipitor       35.729691     32.135155  32.135155
# Paracetamol   33.557047     33.631618  32.811335
# Penicillin    32.657343     33.426573  33.916084

# %%
pivot = df.pivot_table(index='Age Group', columns='Medical Condition', values='Billing Amount', aggfunc='mean')

plt.figure(figsize=(12,8))
sns.heatmap(pivot, annot=True, fmt=".0f",cmap='YlGnBu')
plt.title('Average Billing Amount by Age Group and Medical Condition')
plt.show();
# Out:
# /tmp/ipython-input-2202839105.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = df.pivot_table(index='Age Group', columns='Medical Condition', values='Billing Amount', aggfunc='mean')
